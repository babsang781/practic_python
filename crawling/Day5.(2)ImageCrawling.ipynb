# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup as bs
import os  # 파일 시스템을 위한 라이브러리
from urllib.request import urlretrieve  
# urlretrieve: 이미지의 경로를 파일로 저장시켜주는 라이브러리

# %%
# 폴더를 생성
# 바탕화면에 이미지라는 폴더가 없다면 폴더를 생성해줘!
if not os.path.isdir('C:/Users/smhrd/Desktop/이미지'):
    os.mkdir('C:/Users/smhrd/Desktop/이미지')

# %%
driver = wb.Chrome()
driver.get('https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EC%86%90%ED%9D%A5%EB%AF%BC')

# %%
#bs 컴퓨터가 알아들을 수 있게 변환 해주는 애
soup = bs(driver.page_source,"lxml")
soup
# Out:
# <html data-platform="win32" data-useragent="mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/97.0.4692.71 safari/537.36" lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="손흥민 : 네이버 이미지검색" property="og:title"/> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'손흥민'의 네이버 이미지검색 결과입니다." property="og:description"/> <meta content="'손흥민'의 네이버 이미지검색 결과입니다." lang="ko" name="description"/> <title>손흥민 : 네이버 이미지검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"/><link href="
# ...

# %%
img = soup.select("img._image._listImage")

# %%
# img[0] 는 요소 
img[0]['src']  # 요소 안에 있는 속성만 가져오기
# Out:
# 'https://search.pstatic.net/common/?src=http%3A%2F%2Fimgnews.naver.net%2Fimage%2F5359%2F2021%2F12%2F20%2F0000385640_001_20211220032603220.jpg&type=a340'

# %%
imgSrc = [] 
for i in img:
    imgSrc.append(i['src'])
imgSrc
# Out:
# ['https://search.pstatic.net/common/?src=http%3A%2F%2Fimgnews.naver.net%2Fimage%2F5359%2F2021%2F12%2F20%2F0000385640_001_20211220032603220.jpg&type=a340',
#  'https://search.pstatic.net/common/?src=http%3A%2F%2Fimgnews.naver.net%2Fimage%2F076%2F2021%2F12%2F06%2F2021120701000365700021011_20211206050802518.jpg&type=a340',
#  'https://search.pstatic.net/common/?src=http%3A%2F%2Fimgnews.naver.net%2Fimage%2F311%2F2021%2F12%2F29%2F0001390803_001_20211229021901387.jpg&type=a340',
#  'https://search.pstatic.net/common/?src=http%3A%2F%2Fimgnews.naver.net%2Fimage%2F108%2F2021%2F02%2F08%2F0002930993_001_20210208192202961.jpg&type=a340',
#  '...',
#  '...',
#  'https://search.pstatic.net/common/?src=http%3A%2F%2Fimgnews.naver.net%2Fimage%2F076%2F2021%2F11%2F17%2F2021111701001354800089941_20211117023602851.jpg&type=a340',
# ...

# %%
# urlretrieve 유알엘 값을 이미지로 저장해줌

for i in range(len(imgSrc)):
    urlretrieve(imgSrc[i], 'C:/Users/smhrd/Desktop/이미지/'+str(i)+'.jpg')
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7448/1631388209.py in <module>
#       3 for i in range(len(imgSrc)):
#       4     urlretrieve(imgSrc[i], 'C:/Users/smhrd/Desktop/이미지/'+str(i)+'.jpg')
# ----> 5     time.sleep(1)
#
# KeyboardInterrupt:
